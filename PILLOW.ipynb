# %% [markdown]
# INTRODUCTION TO PILLOW

# %%
from PIL import Image

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
filename = '/content/drive/My Drive/Colab Notebooks/Image Analysis/Images/petal.jpeg'

# %%
img = Image.open(filename)

# %%
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=230x219 at 0x7ABFC7E2E5D0>

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=230x219>

# %% [markdown]
# **CREATE A NEW IMAGE**

# %%
'''
To create a new image, you can use the Image.new() function.
The channel mode, (width, and height), and (channels values) are neeeded to create a new image.

The channel values can be varied, to create a variety of colors.

The values ranges ffrom 0 to 255.

'''


img2 = Image.new('RGB', (400,300), (100, 255, 0))

# %%
print(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7ABFC7E2E9C0>

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %%
filename = '/content/drive/My Drive/Colab Notebooks/Image Analysis/Images/lion.jpeg'

# %%
img3 = Image.open(filename)

img3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %% [markdown]
# **ROTATING IMAGES**

# %%
img3 = img3.rotate(90)

img3
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img3 = img3.rotate(angle= 90, expand= True, fillcolor= 'green')

img3
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
im3 = img3.crop(box = (10, 10, 100, 100))

im3
# Out:
# <PIL.Image.Image image mode=RGB size=90x90>
